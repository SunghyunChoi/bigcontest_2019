# %%
import os
import numpy as np
import pandas as pd
import itertools
from matplotlib import pyplot as plt

# %%
import ipympl
# %matplotlib inline

# %% [markdown]
# # data read

# %%
# matplot setting
import matplotlib as mpl
import matplotlib.pyplot as plt
from matplotlib import font_manager, rc
font_name = font_manager.FontProperties(fname="c:/Windows/Fonts/gulim.ttc").get_name()
#font_name = font_manager.FontProperties(fname="/usr/share/fonts/truetype/nanum/NanumGothic.ttf").get_name()
rc('font', family=font_name)
mpl.rcParams['axes.unicode_minus'] = False
# plt.style.use('dark_background')

# %%
import warnings 
warnings.filterwarnings('ignore')

# %%
df_card_flow = "../../data/가공데이터/df_final.csv"

df_card_flow = pd.read_csv(df_card_flow)

# %%
df_card_flow.head()
# Out:
#    Unnamed: 0          날짜  구_x    동  예보  pm10  co2  vocs  noise  temp  ...  \
# 0           0  2018-04-01  종로구  사직동  좋음   NaN  NaN   NaN    NaN   NaN  ...
# 1           1  2018-04-01  종로구  사직동  좋음   NaN  NaN   NaN    NaN   NaN  ...
# 2           2  2018-04-01  종로구  사직동  좋음   NaN  NaN   NaN    NaN   NaN  ...
# 3           3  2018-04-01  종로구  사직동  좋음   NaN  NaN   NaN    NaN   NaN  ...
# 4           4  2018-04-01  종로구  사직동  좋음   NaN  NaN   NaN    NaN   NaN  ...
#
#    취미&여가활동_비중   사회활동_비중  임신/육아_비중  업종코드  성별코드  나이코드  이용건수  이용금액  구_y  \
# 0    0.004988  0.002467   0.00925    10     F    25    39  4936  종로구
# 1    0.004988  0.002467   0.00925    21     F    25    18   565  종로구
# 2    0.004988  0.002467   0.00925    22     F    25   149  1709  종로구
# 3    0.004988  0.002467   0.00925    34     F    25    13   101  종로구
# 4    0.004988  0.002467   0.00925    40     F    25   556  4611  종로구
#
#    FLOW_POP_CNT
# 0       6892.47
# 1       6892.47
# 2       6892.47
# 3       6892.47
# 4       6892.47
#
# [5 rows x 28 columns]

# %%
#del df_card_flow['Unnamed: 0']
df_card_flow = df_card_flow.drop(columns = ['co2', 'vocs', 'noise', 'temp', 'humi', 'pm25'])

# %%
df_card_flow = df_card_flow.dropna()

# %%
df_card_flow.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1508948 entries, 210 to 1699870
# Data columns (total 22 columns):
# Unnamed: 0      1508948 non-null int64
# 날짜              1508948 non-null object
# 구_x             1508948 non-null object
# 동               1508948 non-null object
# 예보              1508948 non-null object
# pm10            1508948 non-null float64
# 매출지수            1508948 non-null float64
# 식사_비중           1508948 non-null float64
# 간식_비중           1508948 non-null float64
# 마실거리_비중         1508948 non-null float64
# 홈&리빙_비중         1508948 non-null float64
# 헬스&뷰티_비중        1508948 non-null float64
# 취미&여가활동_비중      1508948 non-null float64
# 사회활동_비중         1508948 non-null float64
# 임신/육아_비중        1508948 non-null float64
# 업종코드            1508948 non-null int64
# 성별코드            1508948 non-null object
# 나이코드            1508948 non-null int64
# 이용건수            1508948 non-null int64
# 이용금액            1508948 non-null int64
# 구_y             1508948 non-null object
# FLOW_POP_CNT    1508948 non-null float64
# dtypes: float64(11), int64(5), object(6)
# memory usage: 264.8+ MB

# %%
df_card_flow.성별코드 = df_card_flow.성별코드.replace('F', -1)
df_card_flow.성별코드 = df_card_flow.성별코드.replace('M', 1)

# %%
import pandas_profiling
pandas_profiling.ProfileReport(df_card_flow[['pm10', '성별코드', '나이코드', '이용건수', '이용금액', 'FLOW_POP_CNT']].sample(n=1000), check_correlation = True)
# Out:
# <meta charset="UTF-8">
#
# <style>
#
#         .variablerow {
#             border: 1px solid #e1e1e8;
#             border-top: hidden;
#             padding-top: 2em;
#             padding-bottom: 2em;
#             padding-left: 1em;
#             padding-right: 1em;
#         }
#
#         .headerrow {
#             border: 1px solid #e1e1e8;
#             background-color: #f5f5f5;
#             padding: 2em;
#         }
#         .namecol {
#             margin-top: -1em;
#             overflow-x: auto;
#         }
#
#         .dl-horizontal dt {
#             text-align: left;
#             padding-right: 1em;
#             white-space: normal;
#         }
#
#         .dl-horizontal dd {
#             margin-left: 0;
#         }
#
#         .ignore {
#             opacity: 0.4;
#         }
#
#         .container.pandas-profiling {
#             max-width:975px;
#         }
#
#         .col-md-12 {
#             padding-left: 2em;
#         }
#
#         .indent {
#             margin-left: 1em;
#         }
#
#         .center-img {
#             margin-left: auto !important;
#             margin-right: auto !important;
#             display: block;
#         }
#
#         /* Table example_values */
#             table.example_values {
#                 border: 0;
#             }
#
#             .example_values th {
#                 border: 0;
#                 padding: 0 ;
#                 color: #555;
#                 font-weight: 600;
#             }
#
#             .example_values tr, .example_values td{
#                 border: 0;
#                 padding: 0;
#                 color: #555;
#             }
#
#         /* STATS */
#             table.stats {
#                 border: 0;
#             }
#
#             .stats th {
#                 border: 0;
#                 padding: 0 2em 0 0;
#                 color: #555;
#                 font-weight: 600;
#             }
#
#             .stats tr {
#                 border: 0;
#             }
#
#             .stats td{
#                 color: #555;
#                 padding: 1px;
#                 border: 0;
#             }
#
#
#         /* Sample table */
#             table.sample {
#                 border: 0;
#                 margin-bottom: 2em;
#                 margin-left:1em;
#             }
#             .sample tr {
#                 border:0;
#             }
#             .sample td, .sample th{
#                 padding: 0.5em;
#                 white-space: nowrap;
#                 border: none;
#
#             }
#
#             .sample thead {
#                 border-top: 0;
#                 border-bottom: 2px solid #ddd;
#             }
#
#             .sample td {
#                 width:100%;
#             }
#
#
#         /* There is no good solution available to make the divs equal height and then center ... */
#             .histogram {
#                 margin-top: 3em;
#             }
#         /* Freq table */
#
#             table.freq {
#                 margin-bottom: 2em;
#                 border: 0;
#             }
#             table.freq th, table.freq tr, table.freq td {
#                 border: 0;
#                 padding: 0;
#             }
#
#             .freq thead {
#                 font-weight: 600;
#                 white-space: nowrap;
#                 overflow: hidden;
#                 text-overflow: ellipsis;
#
#             }
#
#             td.fillremaining{
#                 width:auto;
#                 max-width: none;
#             }
#
#             td.number, th.number {
#                 text-align:right ;
#             }
#
#         /* Freq mini */
#             .freq.mini td{
#                 width: 50%;
#                 padding: 1px;
#                 font-size: 12px;
#
#             }
#             table.freq.mini {
#                  width:100%;
#             }
#             .freq.mini th {
#                 overflow: hidden;
#                 text-overflow: ellipsis;
#                 white-space: nowrap;
#                 max-width: 5em;
#                 font-weight: 400;
#                 text-align:right;
#                 padding-right: 0.5em;
#             }
#
#             .missing {
#                 color: #a94442;
#             }
#             .alert, .alert > th, .alert > td {
#                 color: #a94442;
#             }
#
#
#         /* Bars in tables */
#             .freq .bar{
#                 float: left;
#                 width: 0;
#                 height: 100%;
#                 line-height: 20px;
#                 color: #fff;
#                 text-align: center;
#                 background-color: #337ab7;
#                 border-radius: 3px;
#                 margin-right: 4px;
#             }
#             .other .bar {
#                 background-color: #999;
#             }
#             .missing .bar{
#                 background-color: #a94442;
#             }
#             .tooltip-inner {
#                 width: 100%;
#                 white-space: nowrap;
#                 text-align:left;
#             }
#
#             .extrapadding{
#                 padding: 2em;
#             }
#
#             .pp-anchor{
#
#             }
#
# </style>
#
# <div class="container pandas-profiling">
#     <div class="row headerrow highlight">
#         <h1>Overview</h1>
#     </div>
#     <div class="row variablerow">
#     <div class="col-md-6 namecol">
#         <p class="h4">Dataset info</p>
#         <table class="stats" style="margin-left: 1em;">
#             <tbody>
#             <tr>
#                 <th>Number of variables</th>
#                 <td>7 </td>
#             </tr>
#             <tr>
#                 <th>Number of observations</th>
#                 <td>1000 </td>
#             </tr>
#             <tr>
#                 <th>Total Missing (%)</th>
#                 <td>0.0% </td>
#             </tr>
#             <tr>
#                 <th>Total size in memory</th>
#                 <td>54.8 KiB </td>
#             </tr>
#             <tr>
#                 <th>Average record size in memory</th>
#                 <td>56.1 B </td>
#             </tr>
#             </tbody>
#         </table>
#     </div>
#     <div class="col-md-6 namecol">
#         <p class="h4">Variables types</p>
#         <table class="stats" style="margin-left: 1em;">
#             <tbody>
#             <tr>
#                 <th>Numeric</th>
#                 <td>6 </td>
#             </tr>
#             <tr>
#                 <th>Categorical</th>
#                 <td>0 </td>
#             </tr>
#             <tr>
#                 <th>Boolean</th>
#                 <td>1 </td>
#             </tr>
#             <tr>
#                 <th>Date</th>
#                 <td>0 </td>
#             </tr>
#             <tr>
#                 <th>Text (Unique)</th>
#                 <td>0 </td>
#             </tr>
#             <tr>
#                 <th>Rejected</th>
#                 <td>0 </td>
#             </tr>
#             <tr>
#                 <th>Unsupported</th>
#                 <td>0 </td>
#             </tr>
#             </tbody>
#         </table>
#     </div>
# </div>
#     <div class="row headerrow highlight">
#         <h1>Variables</h1>
#     </div>
#     <div class="row variablerow">
#     <div class="col-md-3 namecol">
#         <p class="h4 pp-anchor" id="pp_var_FLOW_POP_CNT">FLOW_POP_CNT<br/>
#             <small>Numeric</small>
#         </p>
#     </div><div class="col-md-6">
#     <div class="row">
#         <div class="col-sm-6">
#             <table class="stats ">
#                 <tr>
#                     <th>Distinct count</th>
#                     <td>994</td>
#                 </tr>
#                 <tr>
#                     <th>Unique (%)</th>
#                     <td>99.4%</td>
#                 </tr>
#                 <tr class="ignore">
#                     <th>Missing (%)</th>
#                     <td>0.0%</td>
#                 </tr>
#                 <tr class="ignore">
#                     <th>Missing (n)</th>
#                     <td>0</td>
#                 </tr>
#                 <tr class="ignore">
#                     <th>Infinite (%)</th>
#                     <td>0.0%</td>
#                 </tr>
#                 <tr class="ignore">
#                     <th>Infinite (n)</th>
#                     <td>0</td>
#                 </tr>
#             </table>
#
#         </div>
#         <div class="col-sm-6">
#             <table class="stats ">
#
#                 <tr>
#                     <th>Mean</th>
#                     <td>4948.5</td>

# %%
df_card_flow = df_card_flow.drop(columns = ['구_y', 'Unnamed: 0'])
df_card_flow = df_card_flow.rename(columns = {'구_x' : '구'})

# %%
for df in [df_card_flow]:
    df['날짜'] = pd.to_datetime(df['날짜'], format = '%Y-%m-%d')

df_card_flow['week'] = df_card_flow['날짜'].dt.weekday

# %%
age_list = set(df_card_flow['나이코드'].values)
sex_list = set(df_card_flow['성별코드'].values)
week_list = set(df_card_flow['week'].values)

sex_age_data = []
sex_age_data_name = []

for age,sex,day in itertools.product(age_list, sex_list, week_list):
    data_name = 'data_' + str(age) + '_' + str(sex) + str(day)
    #print(df_card_flow[(df_card_flow['나이코드'] == age) & (df_card_flow['성별코드'] == sex)].head())
    sex_age_data.append(df_card_flow[(df_card_flow['나이코드'] == age) & (df_card_flow['성별코드'] == sex) & (df_card_flow['week'] == day)])
    sex_age_data_name.append(data_name)

# %%
df_card_flow.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1508948 entries, 210 to 1699870
# Data columns (total 21 columns):
# 날짜              1508948 non-null datetime64[ns]
# 구               1508948 non-null object
# 동               1508948 non-null object
# 예보              1508948 non-null object
# pm10            1508948 non-null float64
# 매출지수            1508948 non-null float64
# 식사_비중           1508948 non-null float64
# 간식_비중           1508948 non-null float64
# 마실거리_비중         1508948 non-null float64
# 홈&리빙_비중         1508948 non-null float64
# 헬스&뷰티_비중        1508948 non-null float64
# 취미&여가활동_비중      1508948 non-null float64
# 사회활동_비중         1508948 non-null float64
# 임신/육아_비중        1508948 non-null float64
# 업종코드            1508948 non-null int64
# 성별코드            1508948 non-null int64
# 나이코드            1508948 non-null int64
# 이용건수            1508948 non-null int64
# 이용금액            1508948 non-null int64
# FLOW_POP_CNT    1508948 non-null float64
# week            1508948 non-null int64
# dtypes: datetime64[ns](1), float64(11), int64(6), object(3)
# memory usage: 253.3+ MB

# %%
for name,data in zip(sex_age_data_name, sex_age_data):
    print(name)
    data = data[['pm10', '이용금액', 'FLOW_POP_CNT']]
    print(data.corr())
    #corr_data = data.corr()
    #plt.plot()
    #plt.imshow(corr_data,cmap='hot',interpolation='nearest')
    #plt.show()
# Out:
# data_65_10
#                   pm10      이용금액  FLOW_POP_CNT
# pm10          1.000000 -0.001726     -0.026004
# 이용금액         -0.001726  1.000000      0.049261
# FLOW_POP_CNT -0.026004  0.049261      1.000000
# data_65_11
#                   pm10      이용금액  FLOW_POP_CNT
# pm10          1.000000  0.014467      0.012802
# 이용금액          0.014467  1.000000      0.068387
# FLOW_POP_CNT  0.012802  0.068387      1.000000
# data_65_12
#                   pm10      이용금액  FLOW_POP_CNT
# pm10          1.000000  0.007014     -0.012983
# 이용금액          0.007014  1.000000      0.053831
# FLOW_POP_CNT -0.012983  0.053831      1.000000
# data_65_13
#                   pm10      이용금액  FLOW_POP_CNT
# pm10          1.000000  0.016042     -0.015050
# 이용금액          0.016042  1.000000      0.054883
# FLOW_POP_CNT -0.015050  0.054883      1.000000
# data_65_14
#                   pm10      이용금액  FLOW_POP_CNT
# pm10          1.000000 -0.004210     -0.052618
# 이용금액         -0.004210  1.000000      0.052194
# FLOW_POP_CNT -0.052618  0.052194      1.000000
# data_65_15
#                   pm10      이용금액  FLOW_POP_CNT
# pm10          1.000000 -0.007834     -0.042258
# 이용금액         -0.007834  1.000000      0.102203
# FLOW_POP_CNT -0.042258  0.102203      1.000000
# data_65_16
#                   pm10      이용금액  FLOW_POP_CNT
# pm10          1.000000 -0.010355     -0.056763
# 이용금액         -0.010355  1.000000      0.139435
# FLOW_POP_CNT -0.056763  0.139435      1.000000
# data_65_-10
#                   pm10      이용금액  FLOW_POP_CNT
# pm10          1.000000  0.013735     -0.035695
# 이용금액          0.013735  1.000000      0.049633
# FLOW_POP_CNT -0.035695  0.049633      1.000000
# data_65_-11
#                   pm10      이용금액  FLOW_POP_CNT
# pm10          1.000000  0.016482      0.018860
# 이용금액          0.016482  1.000000      0.048301
# FLOW_POP_CNT  0.018860  0.048301      1.000000
# data_65_-12
#                  pm10      이용금액  FLOW_POP_CNT
# pm10          1.00000  0.021440     -0.000630
# 이용금액          0.02144  1.000000      0.048375
# FLOW_POP_CNT -0.00063  0.048375      1.000000
# data_65_-13
#                   pm10      이용금액  FLOW_POP_CNT
# pm10          1.000000  0.039248     -0.018192
# 이용금액          0.039248  1.000000      0.045387
# FLOW_POP_CNT -0.018192  0.045387      1.000000
# data_65_-14
#                   pm10      이용금액  FLOW_POP_CNT
# pm10          1.000000  0.003283     -0.035465
# 이용금액          0.003283  1.000000      0.038895
# FLOW_POP_CNT -0.035465  0.038895      1.000000
# data_65_-15
#                   pm10      이용금액  FLOW_POP_CNT
# pm10          1.000000  0.003431     -0.035511
# 이용금액          0.003431  1.000000      0.039283
# FLOW_POP_CNT -0.035511  0.039283      1.000000
# data_65_-16
#                   pm10      이용금액  FLOW_POP_CNT
# pm10          1.000000  0.012663     -0.083777
# 이용금액          0.012663  1.000000      0.050108
# FLOW_POP_CNT -0.083777  0.050108      1.000000
# data_35_10
#                   pm10      이용금액  FLOW_POP_CNT
# pm10          1.000000 -0.006597     -0.100902
# 이용금액         -0.006597  1.000000      0.100938
# FLOW_POP_CNT -0.100902  0.100938      1.000000
# data_35_11
#                   pm10      이용금액  FLOW_POP_CNT
# pm10          1.000000 -0.002080     -0.043652
# 이용금액         -0.002080  1.000000      0.112137
# FLOW_POP_CNT -0.043652  0.112137      1.000000
# data_35_12
#                   pm10      이용금액  FLOW_POP_CNT
# pm10          1.000000  0.001027     -0.092781
# 이용금액          0.001027  1.000000      0.106305
# FLOW_POP_CNT -0.092781  0.106305      1.000000
# data_35_13
#                   pm10      이용금액  FLOW_POP_CNT
# pm10          1.000000  0.022915     -0.121297
# 이용금액          0.022915  1.000000      0.105065
# FLOW_POP_CNT -0.121297  0.105065      1.000000
# data_35_14
#                   pm10      이용금액  FLOW_POP_CNT
# pm10          1.000000  0.001066     -0.117486
# 이용금액          0.001066  1.000000      0.106125
# FLOW_POP_CNT -0.117486  0.106125      1.000000
# data_35_15
#                   pm10      이용금액  FLOW_POP_CNT
# pm10          1.000000 -0.003302     -0.127909
# 이용금액         -0.003302  1.000000      0.097249
# FLOW_POP_CNT -0.127909  0.097249      1.000000
# data_35_16
#                   pm10      이용금액  FLOW_POP_CNT
# pm10          1.000000 -0.008529     -0.168861
# 이용금액         -0.008529  1.000000      0.079682
# FLOW_POP_CNT -0.168861  0.079682      1.000000
# data_35_-10
#                   pm10      이용금액  FLOW_POP_CNT
# pm10          1.000000  0.003613     -0.095876
# 이용금액          0.003613  1.000000      0.111566
# FLOW_POP_CNT -0.095876  0.111566      1.000000
# data_35_-11
#                   pm10      이용금액  FLOW_POP_CNT
# pm10          1.000000 -0.001791     -0.050406
# 이용금액         -0.001791  1.000000      0.080424
# FLOW_POP_CNT -0.050406  0.080424      1.000000
# data_35_-12
#                   pm10     이용금액  FLOW_POP_CNT
# pm10          1.000000  0.00119     -0.076161
# 이용금액          0.001190  1.00000      0.107740
# FLOW_POP_CNT -0.076161  0.10774      1.000000
# data_35_-13
#                   pm10      이용금액  FLOW_POP_CNT
# pm10          1.000000  0.021443     -0.079903
# 이용금액          0.021443  1.000000      0.066879
# FLOW_POP_CNT -0.079903  0.066879      1.000000
# data_35_-14
#                   pm10      이용금액  FLOW_POP_CNT
# pm10          1.000000 -0.003548     -0.094852
# 이용금액         -0.003548  1.000000      0.100938
# FLOW_POP_CNT -0.094852  0.100938      1.000000
# data_35_-15
#                   pm10      이용금액  FLOW_POP_CNT
# pm10          1.000000  0.001161     -0.114554
# 이용금액          0.001161  1.000000      0.084320
# FLOW_POP_CNT -0.114554  0.084320      1.000000
# data_35_-16
#                   pm10      이용금액  FLOW_POP_CNT
# pm10          1.000000 -0.002706     -0.157874
# 이용금액         -0.002706  1.000000      0.056415
# FLOW_POP_CNT -0.157874  0.056415      1.000000
# data_40_10
#                   pm10      이용금액  FLOW_POP_CNT
# pm10          1.000000  0.002477     -0.095169
# 이용금액          0.002477  1.000000      0.104439
# FLOW_POP_CNT -0.095169  0.104439      1.000000
# data_40_11
#                  pm10      이용금액  FLOW_POP_CNT
# pm10          1.00000  0.008820     -0.034980
# 이용금액          0.00882  1.000000      0.107461
# FLOW_POP_CNT -0.03498  0.107461      1.000000
# data_40_12
#                   pm10      이용금액  FLOW_POP_CNT
# pm10          1.000000  0.005739     -0.078733
# 이용금액          0.005739  1.000000      0.095167
# FLOW_POP_CNT -0.078733  0.095167      1.000000
# data_40_13
#                   pm10      이용금액  FLOW_POP_CNT
# pm10          1.000000  0.007164     -0.113927
# 이용금액          0.007164  1.000000      0.097799
# FLOW_POP_CNT -0.113927  0.097799      1.000000
# data_40_14
#                   pm10      이용금액  FLOW_POP_CNT
# pm10          1.000000  0.005669     -0.132900
# 이용금액          0.005669  1.000000      0.092788
# FLOW_POP_CNT -0.132900  0.092788      1.000000
# data_40_15
#                   pm10      이용금액  FLOW_POP_CNT
# pm10          1.000000 -0.001092     -0.126822
# 이용금액         -0.001092  1.000000      0.097512
# FLOW_POP_CNT -0.126822  0.097512      1.000000
# data_40_16
#                   pm10      이용금액  FLOW_POP_CNT
# pm10          1.000000 -0.007189     -0.153779
# 이용금액         -0.007189  1.000000      0.095714
# FLOW_POP_CNT -0.153779  0.095714      1.000000
# data_40_-10
#                   pm10      이용금액  FLOW_POP_CNT
# pm10          1.000000  0.002491     -0.104018
# 이용금액          0.002491  1.000000      0.092402
# FLOW_POP_CNT -0.104018  0.092402      1.000000
# data_40_-11
#                   pm10      이용금액  FLOW_POP_CNT
# pm10          1.000000  0.004354     -0.038763
# 이용금액          0.004354  1.000000      0.083446
# FLOW_POP_CNT -0.038763  0.083446      1.000000
# data_40_-12
#                   pm10      이용금액  FLOW_POP_CNT
# pm10          1.000000  0.008343     -0.078259
# 이용금액          0.008343  1.000000      0.080838
# FLOW_POP_CNT -0.078259  0.080838      1.000000
# data_40_-13
#                   pm10      이용금액  FLOW_POP_CNT
# pm10          1.000000  0.022943     -0.090524
# 이용금액          0.022943  1.000000      0.093411
# FLOW_POP_CNT -0.090524  0.093411      1.000000
# data_40_-14
#                   pm10      이용금액  FLOW_POP_CNT
# pm10          1.000000  0.001201     -0.097370
# 이용금액          0.001201  1.000000      0.092383
# FLOW_POP_CNT -0.097370  0.092383      1.000000
# data_40_-15
#                   pm10      이용금액  FLOW_POP_CNT
# pm10          1.000000  0.004472     -0.104222
# 이용금액          0.004472  1.000000      0.087768
# FLOW_POP_CNT -0.104222  0.087768      1.000000
# data_40_-16
#                   pm10      이용금액  FLOW_POP_CNT
# pm10          1.000000  0.004577     -0.151165
# 이용금액          0.004577  1.000000      0.068471
# FLOW_POP_CNT -0.151165  0.068471      1.000000
# data_45_10
#                   pm10      이용금액  FLOW_POP_CNT
# pm10          1.000000 -0.005308     -0.096482
# 이용금액         -0.005308  1.000000      0.074799
# FLOW_POP_CNT -0.096482  0.074799      1.000000
# data_45_11
#                   pm10      이용금액  FLOW_POP_CNT
# pm10          1.000000  0.001131     -0.034567
# 이용금액          0.001131  1.000000      0.075109
# FLOW_POP_CNT -0.034567  0.075109      1.000000
# data_45_12
#                   pm10      이용금액  FLOW_POP_CNT
# pm10          1.000000  0.003232     -0.074605
# 이용금액          0.003232  1.000000      0.076892
# FLOW_POP_CNT -0.074605  0.076892      1.000000
# data_45_13
#                   pm10      이용금액  FLOW_POP_CNT
# pm10          1.000000  0.017295     -0.107633
# 이용금액          0.017295  1.000000      0.096477
# FLOW_POP_CNT -0.107633  0.096477      1.000000
# data_45_14
#                   pm10      이용금액  FLOW_POP_CNT
# pm10          1.000000  0.004362     -0.121472
# 이용금액          0.004362  1.000000      0.084842
# FLOW_POP_CNT -0.121472  0.084842      1.000000
# data_45_15
#                   pm10      이용금액  FLOW_POP_CNT
# pm10          1.000000 -0.002017     -0.135924
# 이용금액         -0.002017  1.000000      0.095922
# FLOW_POP_CNT -0.135924  0.095922      1.000000
# data_45_16
#                   pm10      이용금액  FLOW_POP_CNT
# pm10          1.000000  0.000999     -0.172579
# 이용금액          0.000999  1.000000      0.096165
# FLOW_POP_CNT -0.172579  0.096165      1.000000
# data_45_-10
#                   pm10      이용금액  FLOW_POP_CNT
# pm10          1.000000  0.007987     -0.098889
# 이용금액          0.007987  1.000000      0.090185
# FLOW_POP_CNT -0.098889  0.090185      1.000000
# data_45_-11
#                   pm10      이용금액  FLOW_POP_CNT
# pm10          1.000000 -0.000785     -0.032154
# 이용금액         -0.000785  1.000000      0.091971
# FLOW_POP_CNT -0.032154  0.091971      1.000000
# data_45_-12
#                   pm10      이용금액  FLOW_POP_CNT
# pm10          1.000000  0.008051     -0.069765
# 이용금액          0.008051  1.000000      0.087891
# FLOW_POP_CNT -0.069765  0.087891      1.000000
# data_45_-13
#                   pm10      이용금액  FLOW_POP_CNT
# pm10          1.000000  0.014123     -0.107456
# 이용금액          0.014123  1.000000      0.085760
# FLOW_POP_CNT -0.107456  0.085760      1.000000
# data_45_-14
#                   pm10      이용금액  FLOW_POP_CNT
# pm10          1.000000 -0.005784     -0.123786
# 이용금액         -0.005784  1.000000      0.098994
# FLOW_POP_CNT -0.123786  0.098994      1.000000
# data_45_-15
#                   pm10      이용금액  FLOW_POP_CNT
# pm10          1.000000 -0.003351     -0.105142
# 이용금액         -0.003351  1.000000      0.100815
# FLOW_POP_CNT -0.105142  0.100815      1.000000
# data_45_-16
#                   pm10      이용금액  FLOW_POP_CNT
# pm10          1.000000 -0.005015     -0.155548
# 이용금액         -0.005015  1.000000      0.085478
# FLOW_POP_CNT -0.155548  0.085478      1.000000
# data_50_10
#                   pm10      이용금액  FLOW_POP_CNT
# pm10          1.000000  0.000878     -0.084127
# 이용금액          0.000878  1.000000      0.007586
# FLOW_POP_CNT -0.084127  0.007586      1.000000
# data_50_11
#                  pm10      이용금액  FLOW_POP_CNT
# pm10          1.00000  0.005290     -0.021700
# 이용금액          0.00529  1.000000      0.007652
# FLOW_POP_CNT -0.02170  0.007652      1.000000
# data_50_12
#                   pm10      이용금액  FLOW_POP_CNT
# pm10          1.000000  0.008720     -0.072551
# 이용금액          0.008720  1.000000      0.005832
# FLOW_POP_CNT -0.072551  0.005832      1.000000
# data_50_13
#                   pm10      이용금액  FLOW_POP_CNT
# pm10          1.000000  0.017727     -0.105331
# 이용금액          0.017727  1.000000      0.017222
# FLOW_POP_CNT -0.105331  0.017222      1.000000
# data_50_14
#                   pm10      이용금액  FLOW_POP_CNT
# pm10          1.000000 -0.003179     -0.110027
# 이용금액         -0.003179  1.000000      0.081522
# FLOW_POP_CNT -0.110027  0.081522      1.000000
# data_50_15
#                   pm10      이용금액  FLOW_POP_CNT
# pm10          1.000000  0.017731     -0.115565
# 이용금액          0.017731  1.000000      0.091641
# FLOW_POP_CNT -0.115565  0.091641      1.000000
# data_50_16
#                   pm10      이용금액  FLOW_POP_CNT
# pm10          1.000000 -0.006831     -0.146828
# 이용금액         -0.006831  1.000000      0.095942
# FLOW_POP_CNT -0.146828  0.095942      1.000000
# data_50_-10
#                   pm10      이용금액  FLOW_POP_CNT
# pm10          1.000000  0.007843     -0.077229
# 이용금액          0.007843  1.000000      0.098784
# FLOW_POP_CNT -0.077229  0.098784      1.000000
# data_50_-11
#                   pm10      이용금액  FLOW_POP_CNT
# pm10          1.000000  0.011296     -0.013836
# 이용금액          0.011296  1.000000      0.093751
# FLOW_POP_CNT -0.013836  0.093751      1.000000
# data_50_-12
#                   pm10      이용금액  FLOW_POP_CNT
# pm10          1.000000  0.005992     -0.067624
# 이용금액          0.005992  1.000000      0.087714
# FLOW_POP_CNT -0.067624  0.087714      1.000000
# data_50_-13
#                   pm10      이용금액  FLOW_POP_CNT
# pm10          1.000000  0.017681     -0.104745
# 이용금액          0.017681  1.000000      0.086404
# FLOW_POP_CNT -0.104745  0.086404      1.000000
# data_50_-14
#                   pm10      이용금액  FLOW_POP_CNT
# pm10          1.000000 -0.004547     -0.118481
# 이용금액         -0.004547  1.000000      0.093519
# FLOW_POP_CNT -0.118481  0.093519      1.000000
# data_50_-15
#                   pm10      이용금액  FLOW_POP_CNT
# pm10          1.000000  0.009636     -0.098519
# 이용금액          0.009636  1.000000      0.094238
# FLOW_POP_CNT -0.098519  0.094238      1.000000
# data_50_-16
#                   pm10      이용금액  FLOW_POP_CNT
# pm10          1.000000  0.002254     -0.148566
# 이용금액          0.002254  1.000000      0.078441
# FLOW_POP_CNT -0.148566  0.078441      1.000000
# data_20_10
#                   pm10      이용금액  FLOW_POP_CNT
# pm10          1.000000  0.000964     -0.069408
# 이용금액          0.000964  1.000000      0.093586
# FLOW_POP_CNT -0.069408  0.093586      1.000000
# data_20_11
#                   pm10      이용금액  FLOW_POP_CNT
# pm10          1.000000  0.002313     -0.013417
# 이용금액          0.002313  1.000000      0.094534
# FLOW_POP_CNT -0.013417  0.094534      1.000000
# data_20_12
#                   pm10      이용금액  FLOW_POP_CNT
# pm10          1.000000 -0.006836     -0.066713
# 이용금액         -0.006836  1.000000      0.092037
# FLOW_POP_CNT -0.066713  0.092037      1.000000
# data_20_13
#                   pm10      이용금액  FLOW_POP_CNT
# pm10          1.000000  0.003744     -0.128919
# 이용금액          0.003744  1.000000      0.098823
# FLOW_POP_CNT -0.128919  0.098823      1.000000
# data_20_14
#                   pm10      이용금액  FLOW_POP_CNT
# pm10          1.000000  0.003218     -0.098003
# 이용금액          0.003218  1.000000      0.105105
# FLOW_POP_CNT -0.098003  0.105105      1.000000
# data_20_15
#                   pm10      이용금액  FLOW_POP_CNT
# pm10          1.000000 -0.002472     -0.099657
# 이용금액         -0.002472  1.000000      0.127312
# FLOW_POP_CNT -0.099657  0.127312      1.000000
# data_20_16
#                   pm10      이용금액  FLOW_POP_CNT
# pm10          1.000000  0.000612     -0.125853
# 이용금액          0.000612  1.000000      0.107709
# FLOW_POP_CNT -0.125853  0.107709      1.000000
# data_20_-10
#                   pm10      이용금액  FLOW_POP_CNT
# pm10          1.000000  0.013381     -0.055263
# 이용금액          0.013381  1.000000      0.101383
# FLOW_POP_CNT -0.055263  0.101383      1.000000
# data_20_-11
#                   pm10      이용금액  FLOW_POP_CNT
# pm10          1.000000  0.001195     -0.002191
# 이용금액          0.001195  1.000000      0.103506
# FLOW_POP_CNT -0.002191  0.103506      1.000000
# data_20_-12
#                   pm10      이용금액  FLOW_POP_CNT
# pm10          1.000000  0.011295     -0.047223
# 이용금액          0.011295  1.000000      0.091178
# FLOW_POP_CNT -0.047223  0.091178      1.000000
# data_20_-13
#                   pm10      이용금액  FLOW_POP_CNT
# pm10          1.000000  0.017777     -0.119311
# 이용금액          0.017777  1.000000      0.099975
# FLOW_POP_CNT -0.119311  0.099975      1.000000
# data_20_-14
#                   pm10      이용금액  FLOW_POP_CNT
# pm10          1.000000  0.007832     -0.082544
# 이용금액          0.007832  1.000000      0.123071
# FLOW_POP_CNT -0.082544  0.123071      1.000000
# data_20_-15
#                   pm10      이용금액  FLOW_POP_CNT
# pm10          1.000000  0.010259     -0.060383
# 이용금액          0.010259  1.000000      0.159443
# FLOW_POP_CNT -0.060383  0.159443      1.000000
# data_20_-16
#                   pm10      이용금액  FLOW_POP_CNT
# pm10          1.000000  0.013578     -0.088709
# 이용금액          0.013578  1.000000      0.132782
# FLOW_POP_CNT -0.088709  0.132782      1.000000
# data_55_10
#                   pm10      이용금액  FLOW_POP_CNT
# pm10          1.000000  0.000580     -0.103636
# 이용금액          0.000580  1.000000      0.063616
# FLOW_POP_CNT -0.103636  0.063616      1.000000
# data_55_11
#                   pm10      이용금액  FLOW_POP_CNT
# pm10          1.000000  0.006006     -0.034562
# 이용금액          0.006006  1.000000      0.067220
# FLOW_POP_CNT -0.034562  0.067220      1.000000
# data_55_12
#                   pm10      이용금액  FLOW_POP_CNT
# pm10          1.000000 -0.001133     -0.083269
# 이용금액         -0.001133  1.000000      0.077173
# FLOW_POP_CNT -0.083269  0.077173      1.000000
# data_55_13
#                   pm10     이용금액  FLOW_POP_CNT
# pm10          1.000000  0.01088     -0.121059
# 이용금액          0.010880  1.00000      0.066650
# FLOW_POP_CNT -0.121059  0.06665      1.000000
# data_55_14
#                   pm10      이용금액  FLOW_POP_CNT
# pm10          1.000000  0.003289     -0.129991
# 이용금액          0.003289  1.000000      0.071445
# FLOW_POP_CNT -0.129991  0.071445      1.000000
# data_55_15
#                   pm10      이용금액  FLOW_POP_CNT
# pm10          1.000000 -0.012728     -0.126699
# 이용금액         -0.012728  1.000000      0.082989
# FLOW_POP_CNT -0.126699  0.082989      1.000000
# data_55_16
#                   pm10      이용금액  FLOW_POP_CNT
# pm10          1.000000 -0.014128     -0.146074
# 이용금액         -0.014128  1.000000      0.111377
# FLOW_POP_CNT -0.146074  0.111377      1.000000
# data_55_-10
#                   pm10      이용금액  FLOW_POP_CNT
# pm10          1.000000  0.008654     -0.091793
# 이용금액          0.008654  1.000000      0.078631
# FLOW_POP_CNT -0.091793  0.078631      1.000000
# data_55_-11
#                   pm10      이용금액  FLOW_POP_CNT
# pm10          1.000000  0.002978     -0.034977
# 이용금액          0.002978  1.000000      0.078232
# FLOW_POP_CNT -0.034977  0.078232      1.000000
# data_55_-12
#                   pm10      이용금액  FLOW_POP_CNT
# pm10          1.000000  0.005786     -0.100004
# 이용금액          0.005786  1.000000      0.076276
# FLOW_POP_CNT -0.100004  0.076276      1.000000
# data_55_-13
#                   pm10      이용금액  FLOW_POP_CNT
# pm10          1.000000  0.012871     -0.116832
# 이용금액          0.012871  1.000000      0.070968
# FLOW_POP_CNT -0.116832  0.070968      1.000000
# data_55_-14
#                   pm10      이용금액  FLOW_POP_CNT
# pm10          1.000000  0.000048     -0.129689
# 이용금액          0.000048  1.000000      0.079505
# FLOW_POP_CNT -0.129689  0.079505      1.000000
# data_55_-15
#                   pm10      이용금액  FLOW_POP_CNT
# pm10          1.000000  0.000396     -0.113019
# 이용금액          0.000396  1.000000      0.076395
# FLOW_POP_CNT -0.113019  0.076395      1.000000
# data_55_-16
#                   pm10      이용금액  FLOW_POP_CNT
# pm10          1.000000 -0.001623     -0.152698
# 이용금액         -0.001623  1.000000      0.066859
# FLOW_POP_CNT -0.152698  0.066859      1.000000
# data_25_10
#                   pm10      이용금액  FLOW_POP_CNT
# pm10          1.000000  0.008928     -0.093164
# 이용금액          0.008928  1.000000      0.110139
# FLOW_POP_CNT -0.093164  0.110139      1.000000
# data_25_11
#                   pm10      이용금액  FLOW_POP_CNT
# pm10          1.000000  0.004010     -0.039673
# 이용금액          0.004010  1.000000      0.098254
# FLOW_POP_CNT -0.039673  0.098254      1.000000
# data_25_12
#                   pm10      이용금액  FLOW_POP_CNT
# pm10          1.000000  0.006505     -0.082739
# 이용금액          0.006505  1.000000      0.092953
# FLOW_POP_CNT -0.082739  0.092953      1.000000
# data_25_13
#                   pm10      이용금액  FLOW_POP_CNT
# pm10          1.000000  0.024755     -0.103829
# 이용금액          0.024755  1.000000      0.101222
# FLOW_POP_CNT -0.103829  0.101222      1.000000
# data_25_14
#                   pm10      이용금액  FLOW_POP_CNT
# pm10          1.000000  0.011940     -0.094839
# 이용금액          0.011940  1.000000      0.098196
# FLOW_POP_CNT -0.094839  0.098196      1.000000
# data_25_15
#                   pm10      이용금액  FLOW_POP_CNT
# pm10          1.000000  0.011705     -0.066605
# 이용금액          0.011705  1.000000      0.118372
# FLOW_POP_CNT -0.066605  0.118372      1.000000
# data_25_16
#                   pm10      이용금액  FLOW_POP_CNT
# pm10          1.000000  0.011295     -0.109777
# 이용금액          0.011295  1.000000      0.103019
# FLOW_POP_CNT -0.109777  0.103019      1.000000
# data_25_-10
#                   pm10      이용금액  FLOW_POP_CNT
# pm10          1.000000  0.018225     -0.057439
# 이용금액          0.018225  1.000000      0.164279
# FLOW_POP_CNT -0.057439  0.164279      1.000000
# data_25_-11
#                   pm10      이용금액  FLOW_POP_CNT
# pm10          1.000000  0.007751     -0.017373
# 이용금액          0.007751  1.000000      0.151171
# FLOW_POP_CNT -0.017373  0.151171      1.000000
# data_25_-12
#                   pm10      이용금액  FLOW_POP_CNT
# pm10          1.000000  0.019375     -0.035995
# 이용금액          0.019375  1.000000      0.157170
# FLOW_POP_CNT -0.035995  0.157170      1.000000
# data_25_-13
#                   pm10      이용금액  FLOW_POP_CNT
# pm10          1.000000  0.025565     -0.041138
# 이용금액          0.025565  1.000000      0.161481
# FLOW_POP_CNT -0.041138  0.161481      1.000000
# data_25_-14
#                   pm10      이용금액  FLOW_POP_CNT
# pm10          1.000000  0.012212     -0.050333
# 이용금액          0.012212  1.000000      0.154900
# FLOW_POP_CNT -0.050333  0.154900      1.000000
# data_25_-15
#                   pm10      이용금액  FLOW_POP_CNT
# pm10          1.000000  0.016444     -0.031022
# 이용금액          0.016444  1.000000      0.147998
# FLOW_POP_CNT -0.031022  0.147998      1.000000
# data_25_-16
#                   pm10      이용금액  FLOW_POP_CNT
# pm10          1.000000  0.012864     -0.062540
# 이용금액          0.012864  1.000000      0.117054
# FLOW_POP_CNT -0.062540  0.117054      1.000000
# data_60_10
#                   pm10      이용금액  FLOW_POP_CNT
# pm10          1.000000 -0.005088     -0.078833
# 이용금액         -0.005088  1.000000      0.108853
# FLOW_POP_CNT -0.078833  0.108853      1.000000
# data_60_11
#                   pm10      이용금액  FLOW_POP_CNT
# pm10          1.000000  0.002338     -0.010854
# 이용금액          0.002338  1.000000      0.091662
# FLOW_POP_CNT -0.010854  0.091662      1.000000
# data_60_12
#                   pm10      이용금액  FLOW_POP_CNT
# pm10          1.000000  0.019343     -0.069622
# 이용금액          0.019343  1.000000      0.102548
# FLOW_POP_CNT -0.069622  0.102548      1.000000
# data_60_13
#                   pm10      이용금액  FLOW_POP_CNT
# pm10          1.000000  0.019152     -0.101293
# 이용금액          0.019152  1.000000      0.077684
# FLOW_POP_CNT -0.101293  0.077684      1.000000
# data_60_14
#                   pm10      이용금액  FLOW_POP_CNT
# pm10          1.000000 -0.012919     -0.119656
# 이용금액         -0.012919  1.000000      0.101851
# FLOW_POP_CNT -0.119656  0.101851      1.000000
# data_60_15
#                   pm10      이용금액  FLOW_POP_CNT
# pm10          1.000000 -0.010574     -0.105350
# 이용금액         -0.010574  1.000000      0.119329
# FLOW_POP_CNT -0.105350  0.119329      1.000000
# data_60_16
#                   pm10      이용금액  FLOW_POP_CNT
# pm10          1.000000 -0.028728     -0.131181
# 이용금액         -0.028728  1.000000      0.168392
# FLOW_POP_CNT -0.131181  0.168392      1.000000
# data_60_-10
#                   pm10      이용금액  FLOW_POP_CNT
# pm10          1.000000 -0.004395     -0.054916
# 이용금액         -0.004395  1.000000      0.072825
# FLOW_POP_CNT -0.054916  0.072825      1.000000
# data_60_-11
#                   pm10      이용금액  FLOW_POP_CNT
# pm10          1.000000  0.019321     -0.011139
# 이용금액          0.019321  1.000000      0.077916
# FLOW_POP_CNT -0.011139  0.077916      1.000000
# data_60_-12
#                   pm10      이용금액  FLOW_POP_CNT
# pm10          1.000000  0.026707     -0.055322
# 이용금액          0.026707  1.000000      0.070257
# FLOW_POP_CNT -0.055322  0.070257      1.000000
# data_60_-13
#                   pm10      이용금액  FLOW_POP_CNT
# pm10          1.000000  0.017502     -0.071826
# 이용금액          0.017502  1.000000      0.074499
# FLOW_POP_CNT -0.071826  0.074499      1.000000
# data_60_-14
#                   pm10      이용금액  FLOW_POP_CNT
# pm10          1.000000  0.000278     -0.092054
# 이용금액          0.000278  1.000000      0.070547
# FLOW_POP_CNT -0.092054  0.070547      1.000000
# data_60_-15
#                   pm10      이용금액  FLOW_POP_CNT
# pm10          1.000000 -0.003434     -0.069250
# 이용금액         -0.003434  1.000000      0.075941
# FLOW_POP_CNT -0.069250  0.075941      1.000000
# data_60_-16
#                   pm10      이용금액  FLOW_POP_CNT
# pm10          1.000000  0.006712     -0.121530
# 이용금액          0.006712  1.000000      0.060641
# FLOW_POP_CNT -0.121530  0.060641      1.000000
# data_30_10
#                   pm10      이용금액  FLOW_POP_CNT
# pm10          1.000000 -0.002026     -0.092688
# 이용금액         -0.002026  1.000000      0.128919
# FLOW_POP_CNT -0.092688  0.128919      1.000000
# data_30_11
#                   pm10      이용금액  FLOW_POP_CNT
# pm10          1.000000 -0.002307     -0.049028
# 이용금액         -0.002307  1.000000      0.119255
# FLOW_POP_CNT -0.049028  0.119255      1.000000
# data_30_12
#                   pm10      이용금액  FLOW_POP_CNT
# pm10          1.000000 -0.002249     -0.076620
# 이용금액         -0.002249  1.000000      0.113795
# FLOW_POP_CNT -0.076620  0.113795      1.000000
# data_30_13
#                   pm10      이용금액  FLOW_POP_CNT
# pm10          1.000000  0.002145     -0.099144
# 이용금액          0.002145  1.000000      0.128266
# FLOW_POP_CNT -0.099144  0.128266      1.000000
# data_30_14
#                   pm10      이용금액  FLOW_POP_CNT
# pm10          1.000000  0.010271     -0.094985
# 이용금액          0.010271  1.000000      0.117523
# FLOW_POP_CNT -0.094985  0.117523      1.000000
# data_30_15
#                   pm10      이용금액  FLOW_POP_CNT
# pm10          1.000000 -0.002106     -0.110681
# 이용금액         -0.002106  1.000000      0.090100
# FLOW_POP_CNT -0.110681  0.090100      1.000000
# data_30_16
#                   pm10      이용금액  FLOW_POP_CNT
# pm10          1.000000  0.000154     -0.141559
# 이용금액          0.000154  1.000000      0.083650
# FLOW_POP_CNT -0.141559  0.083650      1.000000
# data_30_-10
#                   pm10      이용금액  FLOW_POP_CNT
# pm10          1.000000  0.019008     -0.070720
# 이용금액          0.019008  1.000000      0.131989
# FLOW_POP_CNT -0.070720  0.131989      1.000000
# data_30_-11
#                   pm10      이용금액  FLOW_POP_CNT
# pm10          1.000000  0.001646     -0.038950
# 이용금액          0.001646  1.000000      0.135129
# FLOW_POP_CNT -0.038950  0.135129      1.000000
# data_30_-12
#                   pm10      이용금액  FLOW_POP_CNT
# pm10          1.000000  0.003716     -0.043617
# 이용금액          0.003716  1.000000      0.138193
# FLOW_POP_CNT -0.043617  0.138193      1.000000
# data_30_-13
#                   pm10      이용금액  FLOW_POP_CNT
# pm10          1.000000  0.032597     -0.045513
# 이용금액          0.032597  1.000000      0.139026
# FLOW_POP_CNT -0.045513  0.139026      1.000000
# data_30_-14
#                   pm10      이용금액  FLOW_POP_CNT
# pm10          1.000000  0.011080     -0.061476
# 이용금액          0.011080  1.000000      0.134858
# FLOW_POP_CNT -0.061476  0.134858      1.000000
# data_30_-15
#                   pm10      이용금액  FLOW_POP_CNT
# pm10          1.000000 -0.000038     -0.075326
# 이용금액         -0.000038  1.000000      0.106349
# FLOW_POP_CNT -0.075326  0.106349      1.000000
# data_30_-16
#                   pm10      이용금액  FLOW_POP_CNT
# pm10          1.000000  0.007461     -0.121421
# 이용금액          0.007461  1.000000      0.072775
# FLOW_POP_CNT -0.121421  0.072775      1.000000

# %%
df_card_flow.head()
# Out:
#             날짜    구    동  예보       pm10      매출지수     식사_비중     간식_비중  \
# 210 2018-04-01  종로구  사직동  보통  68.306944  1.258473  0.237403  0.257984
# 211 2018-04-01  종로구  사직동  보통  68.306944  1.258473  0.237403  0.257984
# 212 2018-04-01  종로구  사직동  보통  68.306944  1.258473  0.237403  0.257984
# 213 2018-04-01  종로구  사직동  보통  68.306944  1.258473  0.237403  0.257984
# 214 2018-04-01  종로구  사직동  보통  68.306944  1.258473  0.237403  0.257984
#
#       마실거리_비중   홈&리빙_비중  ...  취미&여가활동_비중   사회활동_비중  임신/육아_비중  업종코드  성별코드  \
# 210  0.349826  0.045502  ...    0.004988  0.002467   0.00925    10    -1
# 211  0.349826  0.045502  ...    0.004988  0.002467   0.00925    21    -1
# 212  0.349826  0.045502  ...    0.004988  0.002467   0.00925    22    -1
# 213  0.349826  0.045502  ...    0.004988  0.002467   0.00925    34    -1
# 214  0.349826  0.045502  ...    0.004988  0.002467   0.00925    40    -1
#
#      나이코드  이용건수  이용금액  FLOW_POP_CNT  week
# 210    25    39  4936       6892.47     6
# 211    25    18   565       6892.47     6
# 212    25   149  1709       6892.47     6
# 213    25    13   101       6892.47     6
# 214    25   556  4611       6892.47     6
#
# [5 rows x 21 columns]

# %%
import os

os.getcwd()
# Out:
# 'C:\\Users\\Sunghyun\\Google 드라이브\\SGkaggler\\code\\공용'
